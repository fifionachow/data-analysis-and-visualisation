# %% [markdown]
# # AERO Bird's Eye View on drug development
#
# A proof of concept for the bird’s-eye view that uses ClinicalTrials.gov data and the AERO graphing method to analyze all of the registered clinical trials from 10 large pharmaceutical companies over past 20 years.
#
# Enrolment - Participants who have been recruited, screened, and gave their informed consent.
#
# https://www.statnews.com/2019/07/18/clinical-trials-birds-eye-view-drug-development/

# %%
import pandas as pd
import matplotlib
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv('AERO-BirdsEye-Data.csv')
df.head()
# Out:
#            NCT Sponsor                                              Title  \
# 0  NCT00003305  Sanofi  A Phase II Trial of Aminopterin in Adults and ...
# 1  NCT00003821  Sanofi  Phase II Trial of Aminopterin in Patients With...
# 2  NCT00004025  Sanofi  Phase I/II Trial of the Safety, Immunogenicity...
# 3  NCT00005645  Sanofi  Phase II Trial of ILX295501 Administered Orall...
# 4  NCT00008281  Sanofi  A Multicenter, Open-Label, Randomized, Three-A...
#
#                                              Summary  Start_Year  Start_Month  \
# 0  RATIONALE: Drugs used in chemotherapy use diff...        1997            7
# 1  RATIONALE: Drugs used in chemotherapy use diff...        1998            1
# 2  RATIONALE: Vaccines made from a person's white...        1999            3
# 3  RATIONALE: Drugs used in chemotherapy use diff...        1999            5
# 4  RATIONALE: Drugs used in chemotherapy use diff...        2000           10
#
#              Phase  Enrollment          Status              Condition
# 0          Phase 2          75       Completed               Leukemia
# 1          Phase 2           0       Withdrawn  Endometrial Neoplasms
# 2  Phase 1/Phase 2          36  Unknown status               Melanoma
# 3          Phase 2           0       Withdrawn      Ovarian Neoplasms
# 4          Phase 3           0  Unknown status   Colorectal Neoplasms

# %%
df[df.Status=='Terminated'].Summary.iloc[5]
# Out:
# 'Study to examine the safety and effectiveness of implanted skeletal muscle cells (cells removed from the thigh muscle) into scarred areas of heart muscle after heart attack.'

# %%
# Each development has its own unique ID. Number of trials over the past 20 years
df.NCT.nunique()
# Out:
# 13748

# %% [markdown]
# ## How many trials have the 10 companies sponsored over the past 20 years?

# %%
df.Sponsor.value_counts()
# Out:
# GSK         2473
# Novartis    2320
# Pfizer      1970
# Merck       1770
# Sanofi      1524
# JNJ         1143
# Roche       1095
# Bayer        619
# Gilead       417
# AbbVie       417
# Name: Sponsor, dtype: int64

# %% [markdown]
# ## Statuses of trials sponsored over the past 20 years

# %%
df.Status.value_counts()
# Out:
# Completed                  10568
# Terminated                  1285
# Recruiting                   800
# Active, not recruiting       646
# Withdrawn                    291
# Not yet recruiting           108
# Unknown status                19
# Suspended                     16
# Enrolling by invitation       15
# Name: Status, dtype: int64

# %%
df.Phase.value_counts()
# Out:
# Phase 3            4887
# Phase 2            3596
# Phase 1            2516
# Phase 4            2015
# Phase 1/Phase 2     322
# Phase 2/Phase 3     139
# Early Phase 1        10
# Name: Phase, dtype: int64

# %%
df.isnull().sum()
# Out:
# NCT              0
# Sponsor          0
# Title          144
# Summary          0
# Start_Year       0
# Start_Month      0
# Phase          263
# Enrollment       0
# Status           0
# Condition        0
# dtype: int64

# %%
df[df.Start_Year==2020].Start_Month.unique()
# Out:
# array([3, 5])

# %%
import datetime

df['month_year'] = df[['Start_Month', 'Start_Year']].apply(lambda x: datetime.date(x.Start_Year, x.Start_Month, 1), axis=1)

# %%
df.groupby('Sponsor').agg({'Condition': "nunique", "Start_Year": "min", 'NCT': 'count', 'Enrollment': ['sum', 'median', 'mean', 'min', 'max']})
# Out:
#          Condition Start_Year   NCT Enrollment
#            nunique        min count        sum median        mean min    max
# Sponsor
# AbbVie          90       2000   417     109007  141.0  261.407674   0   6000
# Bayer          170       1998   619     280250  116.0  452.746365   0  30825
# GSK            306       1990  2473    1388740   96.0  561.560857   0  63227
# Gilead          75       1999   417     101029  111.0  242.275779   0   6560
# JNJ            238       1984  1143     343292  121.0  300.342957   0  15526
# Merck          279       1985  1770     946861  154.0  534.949718   0  69274
# Novartis       390       1998  2320     865558  125.5  373.085345   0  14075
# Pfizer         360       1990  1970     774200  112.0  392.994924   0  84496
# Roche          160       1997  1095     399026  122.0  364.407306   0  47208
# Sanofi         266       1993  1524     851931  165.5  559.009843   0  31989

# %%
df.groupby(['Condition', 'Sponsor'])

# %%
sponsor_study_count = df.groupby('Sponsor')['NCT'].count()

# %%
sponsor_status_df = df[(df.Status=='Terminated')|(df.Status=='Completed')].groupby(['Sponsor', 'Status']).agg({'Condition': 'nunique', 'NCT': 'count'})

# %%
sponsor_status_pivot = sponsor_status_df.reset_index().pivot(index='Sponsor', columns='Status', values='NCT')
sponsor_status_pivot['terminated_over_completed'] = sponsor_status_pivot['Terminated']/sponsor_status_pivot['Completed'] * 100
sponsor_status_pivot_joined = sponsor_status_pivot.join(sponsor_study_count)
sponsor_status_pivot_joined['completed_ratio'] = sponsor_status_pivot_joined['Completed']/sponsor_status_pivot_joined['NCT']
sponsor_status_pivot_joined.sort_values('terminated_over_completed')
# Out:
#           Completed  Terminated  terminated_over_completed   NCT  \
# Sponsor
# GSK            2116         146                   6.899811  2473
# AbbVie          247          18                   7.287449   417
# Bayer           470          44                   9.361702   619
# Roche           772          78                  10.103627  1095
# Sanofi         1232         136                  11.038961  1524
# Novartis       1742         194                  11.136625  2320
# JNJ             868         105                  12.096774  1143
# Merck          1360         221                  16.250000  1770
# Gilead          288          48                  16.666667   417
# Pfizer         1473         295                  20.027155  1970
#
#           completed_ratio
# Sponsor
# GSK              0.855641
# AbbVie           0.592326
# Bayer            0.759289
# Roche            0.705023
# Sanofi           0.808399
# Novartis         0.750862
# JNJ              0.759405
# Merck            0.768362
# Gilead           0.690647
# Pfizer           0.747716

# %%
df.groupby('Start_Year').agg({'NCT': 'count', 'Condition': 'nunique', 'Sponsor': 'nunique'})
# Out:
#              NCT  Condition  Sponsor
# Start_Year
# 1984           1          1        1
# 1985           1          1        1
# 1988           3          2        1
# 1989           3          1        1
# 1990           3          3        3
# 1991           2          2        2
# 1992           9          6        4
# 1993          11          9        4
# 1994           5          3        3
# 1995          16         10        3
# 1996          12          8        4
# 1997          35         25        6
# 1998          47         32        8
# 1999          72         47        9
# 2000         113         70       10
# 2001         217        112        9
# 2002         381        168       10
# 2003         607        216       10
# 2004         799        253       10
# 2005         897        276       10
# 2006        1104        286       10
# 2007        1115        284       10
# 2008        1089        282       10
# 2009         964        263       10
# 2010         913        249       10
# 2011         872        269       10
# 2012         802        240       10
# 2013         741        230       10
# 2014         649        203       10
# 2015         669        236       10
# 2016         555        195       10
# 2017         472        176       10
# 2018         518        191       10
# 2019          49         41       10
# 2020           2          2        2

# %% [markdown]
# ## Diseases with most trials over 20 years

# %%
df.groupby('Condition')['NCT'].count().nlargest(n=5)
# Out:
# Condition
# Diabetes Mellitus, Type 2                 536
# Breast Neoplasms                          388
# Pulmonary Disease, Chronic Obstructive    339
# Hypertension                              338
# Asthma                                    334
# Name: NCT, dtype: int64

# %%
## Diseases with the most completed successful Phase 3 trials

# %% [raw]
# df[(df.Phase=='Phase 3') & (df.Status=='Completed')].groupby('Condition').agg({"NCT": "count", "Enrollment": "sum"}).sort_values("NCT", ascending=False).head(20)

# %%
p4_completed = df[(df.Phase=='Phase 4') & (df.Status=='Completed')]

# %%
p4_completed.groupby('Start_Year').agg({'NCT': "count", "Condition": "nunique"})
# Out:
#             NCT  Condition
# Start_Year
# 1992          1          1
# 1996          1          1
# 1997          2          2
# 1998          2          1
# 1999          6          4
# 2000         13         11
# 2001         25         19
# 2002         80         56
# 2003        163         77
# 2004        191        108
# 2005        165         86
# 2006        166         87
# 2007        141         81
# 2008        143         78
# 2009         97         57
# 2010        105         55
# 2011         74         50
# 2012         69         47
# 2013         47         31
# 2014         63         42
# 2015         48         28
# 2016         42         23
# 2017         11          8
# 2018          4          4

# %%
p4_completed[p4_completed.Start_Year==2004].groupby(['Sponsor'])['Condition'].value_counts().nlargest(n=10)
# Out:
# Sponsor   Condition
# Novartis  Hypertension                              13
# Bayer     Erectile Dysfunction                       7
# Novartis  Dermatitis, Atopic                         6
# GSK       Asthma                                     5
# Merck     Rhinitis, Allergic                         4
# GSK       Pulmonary Disease, Chronic Obstructive     3
# Merck     Psoriasis                                  3
# Pfizer    Urinary Incontinence                       3
# Roche     Hepatitis C, Chronic                       3
#           Osteoporosis                               3
# Name: Condition, dtype: int64

# %%
p4_completed.groupby(['Condition', 'Sponsor'])['NCT'].count().nlargest(n=20)
# Out:
# Condition                               Sponsor
# Hypertension                            Novartis    58
# Diabetes Mellitus, Type 2               Sanofi      53
# Schizophrenia                           JNJ         35
# Asthma                                  GSK         33
# Influenza, Human                        Sanofi      28
# Hepatitis B                             GSK         27
# Pulmonary Disease, Chronic Obstructive  GSK         26
# Arthritis, Rheumatoid                   Roche       22
# Erectile Dysfunction                    Pfizer      18
#                                         Bayer       17
# Hepatitis                               Roche       17
# Diabetes Mellitus                       Sanofi      16
# Diabetes Mellitus, Type 2               Novartis    16
# Pulmonary Disease, Chronic Obstructive  Novartis    16
# Hypercholesterolemia                    Merck       15
# Anemia                                  Roche       14
# Arthritis, Rheumatoid                   Pfizer      13
# Asthma                                  Merck       13
# Hypertension                            Pfizer      13
# Alzheimer Disease                       Novartis    12
# Name: NCT, dtype: int64

# %%
p4_completed.groupby('Sponsor').agg({'Condition': 'nunique', 'NCT': 'count'})
# Out:
#           Condition  NCT
# Sponsor
# AbbVie            9   13
# Bayer            33   65
# GSK              71  241
# Gilead           11   24
# JNJ              56  128
# Merck            67  162
# Novartis        105  336
# Pfizer          121  273
# Roche            29  140
# Sanofi           82  277

# %%
condition_sponsor = df.groupby('Condition')['Sponsor'].unique().reset_index()
condition_sponsor['num_sponsor'] = condition_sponsor['Sponsor'].apply(lambda x: len(x))
condition_sponsor[condition_sponsor.num_sponsor==10].Condition.tolist()
# Out:
# ['Arthritis, Rheumatoid',
#  'Breast Neoplasms',
#  'Carcinoma, Non-Small-Cell Lung',
#  'Colitis, Ulcerative',
#  'Infection',
#  'Kidney Diseases',
#  'Leukemia',
#  'Liver Diseases',
#  'Lung Neoplasms',
#  'Lymphoma',
#  'Lymphoma, Non-Hodgkin',
#  'Multiple Myeloma',
#  'Pancreatic Neoplasms',
#  'Prostatic Neoplasms',
#  'Renal Insufficiency']

# %%
condition_1_sponsor = condition_sponsor[condition_sponsor.num_sponsor==1]
condition_1_sponsor['Sponsor'] = condition_1_sponsor['Sponsor'].apply(lambda x: x[0])
condition_1_sponsor.groupby('Sponsor')['Condition'].nunique()
# Out:
# /Users/fionachow/anaconda3/envs/dcuration/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Sponsor
# AbbVie       5
# Bayer       27
# GSK         52
# Gilead       3
# JNJ         36
# Merck       38
# Novartis    91
# Pfizer      72
# Roche       14
# Sanofi      52
# Name: Condition, dtype: int64

# %%
df.groupby(['Condition', 'Phase', "Status"]).agg({'NCT': "count"})
# Out:
#                                                                            NCT
# Condition                          Phase           Status
# ACTH-Secreting Pituitary Adenoma   Phase 2         Active, not recruiting    2
#                                                    Completed                 1
#                                                    Not yet recruiting        1
#                                    Phase 3         Active, not recruiting    1
#                                                    Completed                 3
#                                                    Recruiting                1
#                                    Phase 4         Completed                 1
# Abdominal Abscess                  Phase 3         Completed                 1
#                                    Phase 4         Completed                 1
# Abdominal Neoplasms                Phase 3         Completed                 1
# Abdominal Pain                     Phase 3         Terminated                1
# Acne Vulgaris                      Phase 1         Completed                 7
#                                    Phase 2         Terminated                1
#                                                    Withdrawn                 1
#                                    Phase 3         Completed                 8
#                                                    Terminated                1
#                                    Phase 4         Completed                 7
# Acquired Immunodeficiency Syndrome Phase 1         Completed                 7
#                                                    Recruiting                1
#                                                    Terminated                1
#                                    Phase 1/Phase 2 Completed                 1
#                                    Phase 2         Completed                 5
#                                                    Recruiting                1
#                                                    Withdrawn                 1
#                                    Phase 2/Phase 3 Completed                 1
#                                    Phase 3         Active, not recruiting    1
#                                                    Completed                 8
#                                    Phase 4         Completed                 2
# Acromegaly                         Phase 2         Completed                 3
#                                    Phase 3         Completed                 7
# ...                                                                        ...
# Vomiting                           Phase 1         Terminated                1
#                                    Phase 2         Completed                 2
#                                                    Terminated                1
#                                    Phase 3         Completed                 6
#                                                    Withdrawn                 1
# Von Hippel-Lindau Disease          Phase 2         Completed                 1
# Waldenstrom Macroglobulinemia      Phase 2         Completed                 1
# Warts                              Phase 1         Completed                 1
#                                    Phase 2         Completed                 1
#                                    Phase 3         Completed                 1
# Weight Loss                        Phase 1         Completed                 1
#                                    Phase 2         Completed                 2
#                                    Phase 2/Phase 3 Completed                 1
#                                    Phase 3         Completed                 2
#                                                    Terminated                1
#                                    Phase 4         Completed                 1
# West Nile Fever                    Phase 2         Completed                 2
# Wet Macular Degeneration           Phase 4         Completed                 1
# Whooping Cough                     Phase 1         Completed                 1
#                                    Phase 3         Completed                 1
# Wound Infection                    Phase 3         Completed                 1
# Wounds and Injuries                Phase 2         Completed                 1
#                                                    Recruiting                1
#                                                    Terminated                1
# Yellow Fever                       Phase 3         Completed                 1
# beta-Thalassemia                   Phase 1/Phase 2 Completed                 1
#                                    Phase 2         Completed                 3
#                                                    Recruiting                1
#                                    Phase 3         Completed                 2
#                                    Phase 4         Completed                 1
#
# [3378 rows x 1 columns]

# %%
df.groupby('Sponsor')['Status'].value_counts()
# Out:
# Sponsor   Status
# AbbVie    Completed                   247
#           Recruiting                   67
#           Active, not recruiting       59
#           Terminated                   18
#           Not yet recruiting           14
#           Withdrawn                     6
#           Enrolling by invitation       5
#           Suspended                     1
# Bayer     Completed                   470
#           Active, not recruiting       56
#           Terminated                   44
#           Recruiting                   36
#           Withdrawn                    10
#           Not yet recruiting            3
# GSK       Completed                  2116
#           Terminated                  146
#           Recruiting                   73
#           Withdrawn                    72
#           Active, not recruiting       42
#           Not yet recruiting           12
#           Unknown status               10
#           Suspended                     2
# Gilead    Completed                   288
#           Terminated                   48
#           Active, not recruiting       40
#           Recruiting                   30
#           Withdrawn                     6
#           Enrolling by invitation       4
#           Unknown status                1
# JNJ       Completed                   868
#                                      ...
# Novartis  Recruiting                  181
#           Active, not recruiting      109
#           Withdrawn                    62
#           Not yet recruiting           30
#           Suspended                     1
#           Unknown status                1
# Pfizer    Completed                  1473
#           Terminated                  295
#           Recruiting                   84
#           Active, not recruiting       56
#           Withdrawn                    49
#           Not yet recruiting            8
#           Suspended                     4
#           Enrolling by invitation       1
# Roche     Completed                   772
#           Recruiting                  106
#           Active, not recruiting      104
#           Terminated                   78
#           Withdrawn                    23
#           Not yet recruiting            6
#           Suspended                     4
#           Unknown status                2
# Sanofi    Completed                  1232
#           Terminated                  136
#           Recruiting                   73
#           Active, not recruiting       49
#           Not yet recruiting           13
#           Withdrawn                    13
#           Enrolling by invitation       4
#           Unknown status                4
# Name: Status, Length: 77, dtype: int64

# %%
sponsor_start_year_condition = df.groupby(['Sponsor', 'Start_Year']).agg({'Condition': "nunique"})

# %%
df[df.Enrollment > 0].groupby('Condition').agg({'Enrollment': 'sum', 'NCT': 'count'}).nlargest(n=10, columns='Enrollment')
# Out:
#                                         Enrollment  NCT
# Condition
# Influenza, Human                            347617  318
# Diabetes Mellitus, Type 2                   205315  526
# Rotavirus Infections                        187681   41
# Hypertension                                162705  330
# Breast Neoplasms                            162523  372
# Malaria                                     161656   52
# Diabetes Mellitus                           157546  258
# Pulmonary Disease, Chronic Obstructive      152360  330
# Asthma                                      139490  312
# Arthritis, Rheumatoid                       131826  329

# %%
import math

def concat_this(x):
    print(x.tolist())
    return "_".join(x.tolist())

def placeholder_if_na(x, placeholder_value="UNKNOWN"):
    if isinstance(x, float) and math.isnan(x):
        return placeholder_value
    elif isinstance(x, str) and x.lower=='nan':
        return placeholder_value
    return x

# %%
df['Phase'] = df['Phase'].apply(lambda x: placeholder_if_na(x))
df['Phase'].isnull().sum()
# Out:
# 0

# %%
df['phase_status'] = df[['Phase', 'Status']].apply(lambda x: concat_this(x), axis=1)
# Out:
# ['Phase 2', 'Completed']
# ['Phase 2', 'Withdrawn']
# ['Phase 1/Phase 2', 'Unknown status']
# ['Phase 2', 'Withdrawn']
# ['Phase 3', 'Unknown status']
# ['Phase 1/Phase 2', 'Unknown status']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 1/Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1/Phase 2', 'Terminated']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Terminated']
# ['Phase 1/Phase 2', 'Completed']
# ['Phase 2/Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1/Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['UNKNOWN', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 1/Phase 2', 'Terminated']
# ['Phase 1/Phase 2', 'Terminated']
# ['Phase 2', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1/Phase 2', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['UNKNOWN', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1', 'Terminated']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 2/Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 4', 'Terminated']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['UNKNOWN', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['UNKNOWN', 'Terminated']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 1/Phase 2', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Terminated']
# ['Phase 3', 'Terminated']
# ['Phase 2', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Recruiting']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2/Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 1', 'Terminated']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1/Phase 2', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2/Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Terminated']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 1/Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 1', 'Terminated']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 2/Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2/Phase 3', 'Completed']
# ['Phase 2/Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Terminated']
# ['Phase 3', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Withdrawn']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 3', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 1/Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2/Phase 3', 'Completed']
# ['Phase 1/Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Terminated']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2/Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 4', 'Terminated']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 1', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Terminated']
# ['Phase 1/Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 1', 'Withdrawn']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Terminated']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Terminated']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2/Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 1/Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 2', 'Completed']
# ['Phase 1', 'Terminated']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Recruiting']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Terminated']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 1', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Terminated']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 3', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Active, not recruiting']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Terminated']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 2', 'Active, not recruiting']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Terminated']
# ['Phase 1', 'Terminated']
# ['Phase 4', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 1/Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 3', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Terminated']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Terminated']
# ['Phase 3', 'Terminated']
# ['Phase 3', 'Terminated']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Terminated']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Terminated']
# ['Phase 2', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Terminated']
# ['Phase 1', 'Completed']
# ['Phase 2', 'Completed']
# ['UNKNOWN', 'Terminated']
# ['Phase 3', 'Terminated']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Terminated']
# ['Phase 2', 'Completed']
# ['Phase 1/Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 2', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 2', 'Terminated']
# ['Phase 3', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Active, not recruiting']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1/Phase 2', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 3', 'Terminated']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Terminated']
# ['Phase 2', 'Completed']
# ['Phase 1/Phase 2', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 1', 'Terminated']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Terminated']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Withdrawn']
# ['Phase 4', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Terminated']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1', 'Terminated']
# ['Phase 2', 'Terminated']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Terminated']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 4', 'Terminated']
# ['Phase 1/Phase 2', 'Terminated']
# ['Phase 4', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1', 'Terminated']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['UNKNOWN', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1/Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1/Phase 2', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 1/Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['UNKNOWN', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Terminated']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Terminated']
# ['Phase 2', 'Withdrawn']
# ['Phase 1', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1/Phase 2', 'Terminated']
# ['Phase 3', 'Completed']
# ['UNKNOWN', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 4', 'Terminated']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1/Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1/Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2/Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Terminated']
# ['Phase 4', 'Terminated']
# ['Phase 1/Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1/Phase 2', 'Active, not recruiting']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Terminated']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Terminated']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 4', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 4', 'Terminated']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2/Phase 3', 'Completed']
# ['Phase 2/Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Withdrawn']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 1/Phase 2', 'Completed']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1/Phase 2', 'Recruiting']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Unknown status']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 4', 'Recruiting']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Withdrawn']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Terminated']
# ['Phase 2', 'Terminated']
# ['Phase 2', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Terminated']
# ['Phase 1', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 4', 'Active, not recruiting']
# ['Phase 1/Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 1/Phase 2', 'Recruiting']
# ['Phase 3', 'Completed']
# ['Phase 1/Phase 2', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Terminated']
# ['Phase 1', 'Completed']
# ['Phase 1/Phase 2', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 1/Phase 2', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Terminated']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['UNKNOWN', 'Completed']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Terminated']
# ['Phase 4', 'Completed']
# ['Phase 1/Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1/Phase 2', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1/Phase 2', 'Recruiting']
# ['Phase 2', 'Completed']
# ['Phase 1', 'Active, not recruiting']
# ['Phase 1/Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Completed']
# ['UNKNOWN', 'Terminated']
# ['Phase 1', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1/Phase 2', 'Terminated']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2/Phase 3', 'Recruiting']
# ['Phase 2', 'Enrolling by invitation']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2/Phase 3', 'Enrolling by invitation']
# ['Phase 2', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 1/Phase 2', 'Enrolling by invitation']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['UNKNOWN', 'Completed']
# ['Phase 2', 'Withdrawn']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2/Phase 3', 'Active, not recruiting']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 1/Phase 2', 'Recruiting']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 1', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Active, not recruiting']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Terminated']
# ['Phase 1', 'Completed']
# ['Phase 1', 'Recruiting']
# ['Phase 3', 'Completed']
# ['Phase 1/Phase 2', 'Active, not recruiting']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 1', 'Withdrawn']
# ['Phase 4', 'Recruiting']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 4', 'Recruiting']
# ['Phase 2', 'Active, not recruiting']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Recruiting']
# ['Phase 3', 'Completed']
# ['Phase 1', 'Recruiting']
# ['Phase 1', 'Recruiting']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Withdrawn']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Enrolling by invitation']
# ['Phase 1', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 1/Phase 2', 'Active, not recruiting']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 1', 'Active, not recruiting']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1/Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 4', 'Completed']
# ['UNKNOWN', 'Completed']
# ['Phase 2', 'Active, not recruiting']
# ['Phase 1', 'Completed']
# ['Phase 2', 'Active, not recruiting']
# ['Phase 4', 'Completed']
# ['Phase 1', 'Withdrawn']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Withdrawn']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Not yet recruiting']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Recruiting']
# ['Phase 3', 'Recruiting']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 1', 'Recruiting']
# ['Phase 1/Phase 2', 'Active, not recruiting']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 2', 'Active, not recruiting']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Recruiting']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Recruiting']
# ['Phase 4', 'Active, not recruiting']
# ['Phase 2', 'Active, not recruiting']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Recruiting']
# ['Phase 4', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Active, not recruiting']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 1', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Recruiting']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 2', 'Recruiting']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 2', 'Terminated']
# ['Phase 3', 'Recruiting']
# ['Phase 2', 'Recruiting']
# ['Phase 1', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 1', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Recruiting']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Recruiting']
# ['Phase 1/Phase 2', 'Recruiting']
# ['Phase 1', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 1/Phase 2', 'Completed']
# ['Phase 2', 'Terminated']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 4', 'Terminated']
# ['Phase 3', 'Recruiting']
# ['Phase 1', 'Recruiting']
# ['Phase 3', 'Completed']
# ['Phase 1/Phase 2', 'Recruiting']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 2', 'Recruiting']
# ['Phase 4', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Recruiting']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Recruiting']
# ['Phase 1', 'Active, not recruiting']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 4', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 3', 'Recruiting']
# ['Phase 4', 'Recruiting']
# ['Phase 1/Phase 2', 'Recruiting']
# ['Phase 3', 'Recruiting']
# ['Phase 1', 'Recruiting']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 1', 'Completed']
# ['Phase 2', 'Recruiting']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 4', 'Active, not recruiting']
# ['Phase 1', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Recruiting']
# ['Phase 3', 'Recruiting']
# ['Phase 1', 'Not yet recruiting']
# ['Phase 3', 'Terminated']
# ['Phase 1', 'Completed']
# ['Phase 2', 'Not yet recruiting']
# ['Phase 4', 'Recruiting']
# ['Phase 1', 'Recruiting']
# ['Phase 2', 'Recruiting']
# ['Phase 1', 'Recruiting']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Recruiting']
# ['Phase 3', 'Recruiting']
# ['Phase 3', 'Recruiting']
# ['Phase 3', 'Recruiting']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Recruiting']
# ['Phase 2/Phase 3', 'Recruiting']
# ['Phase 3', 'Recruiting']
# ['Phase 3', 'Recruiting']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Recruiting']
# ['Phase 3', 'Not yet recruiting']
# ['Phase 3', 'Recruiting']
# ['Phase 3', 'Recruiting']
# ['Phase 3', 'Completed']
# ['Phase 1/Phase 2', 'Recruiting']
# ['Phase 3', 'Recruiting']
# ['Phase 3', 'Recruiting']
# ['Phase 4', 'Recruiting']
# ['Phase 3', 'Recruiting']
# ['Phase 3', 'Not yet recruiting']
# ['Phase 3', 'Recruiting']
# ['Phase 1/Phase 2', 'Not yet recruiting']
# ['Phase 2', 'Recruiting']
# ['Phase 3', 'Recruiting']
# ['Phase 3', 'Recruiting']
# ['Phase 3', 'Recruiting']
# ['Phase 4', 'Not yet recruiting']
# ['Phase 1', 'Recruiting']
# ['Phase 3', 'Recruiting']
# ['Phase 2', 'Recruiting']
# ['Phase 3', 'Recruiting']
# ['Phase 3', 'Not yet recruiting']
# ['Phase 1', 'Recruiting']
# ['Phase 3', 'Not yet recruiting']
# ['Phase 3', 'Recruiting']
# ['Phase 4', 'Not yet recruiting']
# ['Phase 3', 'Recruiting']
# ['Phase 3', 'Not yet recruiting']
# ['Phase 3', 'Not yet recruiting']
# ['Phase 1/Phase 2', 'Not yet recruiting']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2/Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Terminated']
# ['Phase 2/Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['UNKNOWN', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 1/Phase 2', 'Completed']
# ['Phase 1/Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1/Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Terminated']
# ['Phase 2', 'Terminated']
# ['Phase 1', 'Completed']
# ['Phase 2/Phase 3', 'Completed']
# ['Phase 1/Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 1/Phase 2', 'Completed']
# ['Phase 2', 'Terminated']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Terminated']
# ['Phase 2/Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 2/Phase 3', 'Completed']
# ['Phase 2/Phase 3', 'Terminated']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 1/Phase 2', 'Terminated']
# ['Phase 2', 'Withdrawn']
# ['Phase 1', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Terminated']
# ['Phase 1/Phase 2', 'Completed']
# ['Phase 2', 'Terminated']
# ['Phase 1/Phase 2', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 1/Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2/Phase 3', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 3', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 1/Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 2', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 2', 'Terminated']
# ['Phase 2', 'Completed']
# ['Phase 2/Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Terminated']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 1', 'Terminated']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 1/Phase 2', 'Completed']
# ['Phase 1/Phase 2', 'Terminated']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 1/Phase 2', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Withdrawn']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2/Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2/Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 1/Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 4', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Withdrawn']
# ['Phase 3', 'Terminated']
# ['UNKNOWN', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ...
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Terminated']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Withdrawn']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 3', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Withdrawn']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 1', 'Completed']
# ['Phase 2', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Active, not recruiting']
# ['Phase 2', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 1', 'Completed']
# ['Phase 2', 'Completed']
# ['UNKNOWN', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['UNKNOWN', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Active, not recruiting']
# ['Phase 2', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 2', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 1', 'Terminated']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 3', 'Terminated']
# ['Phase 2', 'Withdrawn']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 2/Phase 3', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 1', 'Withdrawn']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Active, not recruiting']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 1', 'Withdrawn']
# ['Phase 1', 'Completed']
# ['Phase 2', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 4', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 2', 'Completed']
# ['Phase 1/Phase 2', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 2', 'Completed']
# ['UNKNOWN', 'Terminated']
# ['Phase 1', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1/Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Withdrawn']
# ['Phase 2', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 3', 'Withdrawn']
# ['Phase 1', 'Completed']
# ['Phase 4', 'Active, not recruiting']
# ['Phase 2', 'Terminated']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Unknown status']
# ['Phase 2', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Withdrawn']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 2', 'Active, not recruiting']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 2', 'Terminated']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 1', 'Active, not recruiting']
# ['Phase 2', 'Terminated']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 1/Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Active, not recruiting']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 3', 'Completed']
# ['Phase 1/Phase 2', 'Active, not recruiting']
# ['Phase 2', 'Active, not recruiting']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 2', 'Terminated']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1', 'Active, not recruiting']
# ['Phase 1', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Recruiting']
# ['UNKNOWN', 'Completed']
# ['Phase 3', 'Completed']
# ['UNKNOWN', 'Completed']
# ['Phase 2', 'Active, not recruiting']
# ['Phase 4', 'Suspended']
# ['Phase 3', 'Recruiting']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Active, not recruiting']
# ['Phase 3', 'Recruiting']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 4', 'Recruiting']
# ['UNKNOWN', 'Completed']
# ['Phase 3', 'Recruiting']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Recruiting']
# ['Phase 1', 'Active, not recruiting']
# ['Phase 2', 'Withdrawn']
# ['Phase 3', 'Recruiting']
# ['Phase 1', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1/Phase 2', 'Terminated']
# ['Phase 1', 'Active, not recruiting']
# ['Phase 1', 'Terminated']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 1/Phase 2', 'Recruiting']
# ['Phase 3', 'Active, not recruiting']
# ['UNKNOWN', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Suspended']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 1', 'Completed']
# ['Phase 2', 'Active, not recruiting']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Recruiting']
# ['UNKNOWN', 'Terminated']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 3', 'Recruiting']
# ['UNKNOWN', 'Completed']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 3', 'Terminated']
# ['Phase 4', 'Recruiting']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 1', 'Recruiting']
# ['Phase 1', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 1', 'Active, not recruiting']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Active, not recruiting']
# ['UNKNOWN', 'Terminated']
# ['Phase 2', 'Terminated']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Terminated']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 2', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 1', 'Suspended']
# ['Phase 1/Phase 2', 'Active, not recruiting']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Recruiting']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Active, not recruiting']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Recruiting']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 1', 'Active, not recruiting']
# ['Phase 1', 'Completed']
# ['Phase 1/Phase 2', 'Active, not recruiting']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['UNKNOWN', 'Completed']
# ['Phase 1', 'Recruiting']
# ['Phase 3', 'Completed']
# ['Phase 1', 'Terminated']
# ['Phase 4', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 1', 'Active, not recruiting']
# ['Phase 4', 'Terminated']
# ['Phase 2', 'Completed']
# ['UNKNOWN', 'Completed']
# ['Phase 1', 'Recruiting']
# ['Phase 1', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 1', 'Completed']
# ['Phase 4', 'Terminated']
# ['Phase 1/Phase 2', 'Active, not recruiting']
# ['Phase 1', 'Recruiting']
# ['Phase 2', 'Active, not recruiting']
# ['Phase 1/Phase 2', 'Active, not recruiting']
# ['Phase 1', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 1', 'Recruiting']
# ['Phase 3', 'Recruiting']
# ['Phase 4', 'Recruiting']
# ['Phase 1/Phase 2', 'Recruiting']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 1', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1/Phase 2', 'Terminated']
# ['Phase 1/Phase 2', 'Completed']
# ['Phase 1/Phase 2', 'Active, not recruiting']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 3', 'Terminated']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Terminated']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 2', 'Active, not recruiting']
# ['Phase 2', 'Completed']
# ['Phase 4', 'Completed']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 3', 'Terminated']
# ['Phase 4', 'Completed']
# ['Phase 1', 'Completed']
# ['Phase 1/Phase 2', 'Active, not recruiting']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 3', 'Completed']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 1', 'Active, not recruiting']
# ['Phase 1', 'Completed']
# ['Phase 2/Phase 3', 'Completed']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 4', 'Completed']
# ['Phase 1', 'Active, not recruiting']
# ['Phase 1', 'Suspended']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 2', 'Recruiting']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 2/Phase 3', 'Active, not recruiting']
# ['Phase 1', 'Completed']
# ['Phase 2/Phase 3', 'Active, not recruiting']
# ['Phase 2', 'Active, not recruiting']
# ['Phase 2', 'Active, not recruiting']
# ['Phase 2', 'Terminated']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 2', 'Active, not recruiting']
# ['Phase 2', 'Active, not recruiting']
# ['UNKNOWN', 'Completed']
# ['Phase 1', 'Recruiting']
# ['Phase 2', 'Recruiting']
# ['Phase 1', 'Recruiting']
# ['Phase 1', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 3', 'Recruiting']
# ['Phase 2', 'Recruiting']
# ['Phase 3', 'Recruiting']
# ['Phase 1', 'Recruiting']
# ['Phase 2', 'Completed']
# ['Phase 2/Phase 3', 'Recruiting']
# ['Phase 1', 'Recruiting']
# ['Phase 1', 'Recruiting']
# ['Phase 3', 'Recruiting']
# ['Phase 1', 'Recruiting']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 3', 'Recruiting']
# ['Phase 2', 'Active, not recruiting']
# ['Phase 2', 'Active, not recruiting']
# ['Phase 1', 'Recruiting']
# ['Phase 3', 'Recruiting']
# ['Phase 3', 'Recruiting']
# ['Phase 1/Phase 2', 'Recruiting']
# ['Phase 1', 'Completed']
# ['Phase 2', 'Active, not recruiting']
# ['Phase 3', 'Recruiting']
# ['Phase 1/Phase 2', 'Recruiting']
# ['Phase 1', 'Completed']
# ['Phase 2/Phase 3', 'Recruiting']
# ['Phase 1', 'Recruiting']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Recruiting']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 1/Phase 2', 'Recruiting']
# ['Phase 3', 'Recruiting']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 3', 'Recruiting']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 1', 'Recruiting']
# ['UNKNOWN', 'Recruiting']
# ['Phase 2', 'Completed']
# ['Phase 3', 'Recruiting']
# ['Phase 3', 'Recruiting']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 3', 'Active, not recruiting']
# ['Phase 1/Phase 2', 'Recruiting']
# ['Phase 1/Phase 2', 'Recruiting']
# ['Phase 4', 'Recruiting']
# ['Phase 2', 'Recruiting']
# ['Phase 1', 'Recruiting']
# ['Phase 1', 'Completed']
# ['Phase 4', 'Recruiting']
# ['Phase 1/Phase 2', 'Recruiting']
# ['Phase 3', 'Recruiting']
# ['Phase 4', 'Recruiting']
# ['Phase 1/Phase 2', 'Recruiting']
# ['Phase 2/Phase 3', 'Recruiting']
# ['Phase 2', 'Active, not recruiting']
# ['Phase 1', 'Withdrawn']
# ['Phase 3', 'Recruiting']
# ['Phase 1', 'Completed']
# ['Phase 1/Phase 2', 'Recruiting']
# ['Phase 3', 'Recruiting']
# ['Phase 3', 'Recruiting']
# ['Phase 3', 'Recruiting']
# ['UNKNOWN', 'Recruiting']
# ['Phase 3', 'Recruiting']
# ['Phase 3', 'Recruiting']
# ['Phase 3', 'Recruiting']
# ['Phase 1', 'Recruiting']
# ['Phase 3', 'Recruiting']
# ['Phase 1', 'Recruiting']
# ['UNKNOWN', 'Recruiting']
# ['Phase 3', 'Recruiting']
# ['Phase 3', 'Recruiting']
# ['Phase 2', 'Recruiting']
# ['Phase 3', 'Recruiting']
# ['Phase 3', 'Recruiting']
# ['Phase 1', 'Completed']
# ['Phase 3', 'Recruiting']
# ['UNKNOWN', 'Recruiting']
# ['Phase 2', 'Recruiting']
# ['Phase 1/Phase 2', 'Recruiting']
# ['Phase 2', 'Recruiting']
# ['Phase 1', 'Recruiting']
# ['Phase 2', 'Recruiting']
# ['Phase 4', 'Recruiting']
# ['Phase 3', 'Recruiting']
# ['Phase 1', 'Recruiting']
# ['Phase 3', 'Recruiting']
# ['Phase 3', 'Recruiting']
# ['Phase 2', 'Not yet recruiting']
# ['Phase 3', 'Recruiting']
# ['Phase 3', 'Recruiting']
# ['Phase 3', 'Recruiting']
# ['Phase 1', 'Recruiting']
# ['Phase 2', 'Recruiting']
# ['Phase 1', 'Recruiting']
# ['Phase 2', 'Not yet recruiting']
# ['Phase 1/Phase 2', 'Recruiting']
# ['Phase 1/Phase 2', 'Recruiting']
# ['Phase 3', 'Recruiting']
# ['Phase 3', 'Recruiting']
# ['Phase 3', 'Recruiting']
# ['Phase 3', 'Withdrawn']
# ['Phase 1', 'Not yet recruiting']
# ['Phase 1', 'Recruiting']
# ['Phase 3', 'Recruiting']
# ['Phase 1', 'Recruiting']
# ['Phase 3', 'Not yet recruiting']
# ['Phase 1', 'Not yet recruiting']
# ['Phase 2', 'Not yet recruiting']

# %%
for condition, groupdf in df.groupby(['Condition', 'Sponsor']):
    print(f"-----{condition} : {groupdf.shape[0]}-----")
    print(groupdf[['Title', 'Enrollment', 'Condition', 'month_year', 'phase_status']].head(2))
    print()
    print(groupdf[['NCT', 'Summary']])
    break
# Out:
# -----('ACTH-Secreting Pituitary Adenoma', 'Novartis') : 10-----
#                                                   Title  Enrollment  \
# 3745  Extension Study to Assess the Safety and Effic...          19
# 4090  A Randomized, Double-blind Study to Assess the...         162
#
#                              Condition  month_year       phase_status
# 3745  ACTH-Secreting Pituitary Adenoma  2004-08-01  Phase 2_Completed
# 4090  ACTH-Secreting Pituitary Adenoma  2006-12-01  Phase 3_Completed
#
#               NCT                                            Summary
# 3745  NCT00171951  Cushing's disease is a rare serious condition ...
# 4090  NCT00434148  This study will evaluate the safety and effica...
# 4853  NCT01331239  This exploratory study is a proof of concept s...
# 4895  NCT01374906  This is a randomized, double-blind, multicente...
# 5052  NCT01582061  This study provided access to pasireotide sc i...
# 5283  NCT01915303  This study is to assess whether pasireotide al...
# 5360  NCT02060383  The study aims to demonstrate that pasireotide...
# 5408  NCT02180217  The study aims to confirm long-term efficacy a...
# 5571  NCT02697734  Purpose of study is to aim to confirm efficacy...
# 5803  NCT03708900  Multicenter, open-label, non-comparative study...

# %%
df[df['Status']=='Completed']
# Out:
#                NCT Sponsor                                              Title  \
# 0      NCT00003305  Sanofi  A Phase II Trial of Aminopterin in Adults and ...
# 6      NCT00012389  Sanofi  A Multicenter, Open-Label, Randomized, Two-Arm...
# 7      NCT00017459  Sanofi  The International Tirazone Triple Trial (i3T):...
# 8      NCT00021255  Sanofi  Multicenter Phase III Randomized Trial Compari...
# 9      NCT00025896  Sanofi  A Prospective Multinational, Multicenter, Clin...
# 10     NCT00029822  Sanofi  Long-Term, Efficacy and Safety of Alfuzosin 10...
# 11     NCT00029835  Sanofi  A Randomized, Double-Blind, Placebo-Controlled...
# 12     NCT00029848  Sanofi  A Randomized, Double-Blind, Placebo-Controlled...
# 13     NCT00029861  Sanofi  A Randomized, Double-Blind, Placebo-Controlled...
# 14     NCT00032734  Sanofi  A Randomized, Double-Blind, Placebo-Controlled...
# 15     NCT00032747  Sanofi  A Multicenter, Randomized, Placebo-Controlled,...
# 16     NCT00034294  Sanofi  A Randomized, Double-Blind Study of GT160-246 ...
# 17     NCT00034918  Sanofi  An Open-label, Multicenter Phase II Study to A...
# 18     NCT00042341  Sanofi  A Phase II, Open Label Study of Clofarabine in...
# 19     NCT00042354  Sanofi  A Phase II, Open Label Study of Clofarabine in...
# 20     NCT00043784  Sanofi  A Prospective, Randomized, Open-Label, Multice...
# 21     NCT00044447  Sanofi  A Double-Blind, Placebo-Controlled, Parallel G...
# 22     NCT00044811  Sanofi  A Multicenter, Double-Blind, Randomized, Paral...
# 23     NCT00044824  Sanofi  A Multicenter, Double-Blind, Randomized, Paral...
# 24     NCT00044889  Sanofi  A Phase II, Open-Label Study of Clofarabine in...
# 25     NCT00045955  Sanofi  A Multicenter, Open-Label, Randomized, Paralle...
# 26     NCT00046150  Sanofi  12-Week, Multinational, Multicenter, Controlle...
# 27     NCT00046462  Sanofi  Substituting Lantus®(Insulin Glargine[rDNAorig...
# 28     NCT00046501  Sanofi  Morning LANTUS v. Intermediate-acting Insulin ...
# 29     NCT00046683  Sanofi  A Phase III Study to Evaluate the Efficacy and...
# 30     NCT00047788  Sanofi  A Phase Two Study of ZD6474 in Patients With R...
# 31     NCT00047840  Sanofi  A Randomized, Double-blind, Multicenter, Phase...
# 32     NCT00050323  Sanofi  Phase 1/2 Study to Assess the Safety and Effic...
# 33     NCT00050778  Sanofi  A Phase II, Randomized, Open-Label, Three-Arm ...
# 34     NCT00050817  Sanofi  A Phase III, Multicenter, Multinational, Rando...
# ...            ...     ...                                                ...
# 13585  NCT02723071   Roche  An Open-label, Multicentre, Dose-escalating Ph...
# 13587  NCT02731131   Roche  A Randomized, Pilot, Open-Label, Monocenter, E...
# 13588  NCT02732639   Roche  Open-label, Multicenter, Trial Evaluating Effi...
# 13589  NCT02733419   Roche  Open-label, Randomised and Multi-center Study ...
# 13590  NCT02736721   Roche  Multicenter Open Label Expanded Access-Program...
# 13591  NCT02738970   Roche  A Phase I, Open-Label, Two-Part, Multicenter P...
# 13594  NCT02748213   Roche  An Open-Label, Randomized Phase II Study of He...
# 13595  NCT02761629   Roche  Randomized, Multi-Center, Phase IV, Comparativ...
# 13599  NCT02774278   Roche  MERIT - A Phase II Marker Identification Trial...
# 13600  NCT02782845   Roche  Expanded Access Program of Pegfilgrastim in Pa...
# 13603  NCT02791269   Roche  Expanded Access Program of PEGASYS® (Peg Inter...
# 13604  NCT02792179   Roche  A Pilot Longitudinal Follow-Up Study of Tau Bu...
# 13607  NCT02806505   Roche  A Randomized, Open-Label, Multicenter, Paralle...
# 13611  NCT02824055   Roche                                                NaN
# 13612  NCT02829775   Roche  Extension Protocol for Patients With Chronic M...
# 13614  NCT02846428   Roche  An Open-Label, Multicenter, Randomized, Phase ...
# 13617  NCT02864199   Roche  Non-Randomized, Multicenter Study to Evaluate ...
# 13624  NCT02913443   Roche  A Multi-Center, Open Label, Phase I, Dose Find...
# 13632  NCT02952911   Roche                                                NaN
# 13636  NCT02975388   Roche  A Multi-Center, Open-Label, Two-Part Study to ...
# 13637  NCT02999672   Roche  Phase II, Exploratory, Multicenter, Non Random...
# 13638  NCT03001219   Roche  A Randomized, Double-Blind, Placebo-Controlled...
# 13645  NCT03038880   Roche  STAIRWAY: Simultaneous Blockade of Angiopoieti...
# 13659  NCT03153163   Roche  A Phase I Study of Pharmacokinetics and Safety...
# 13663  NCT03174795   Roche  A Non-Randomized, Open-Label, One Treatment, O...
# 13666  NCT03182504   Roche  A Non-Randomized, Open Label, One Treatment, O...
# 13676  NCT03271541   Roche  A Phase II, Single Arm, Multicenter, Proof-of-...
# 13686  NCT03293992   Roche  A Phase I, Multi-Center, Randomized, Adaptive,...
# 13696  NCT03380780   Roche  A Single-Center, Open-Label, Single Dose Study...
# 13714  NCT03507569   Roche  A Non-Randomized Open Label, Adaptive, Paralle...
#
#                                                  Summary  Start_Year  \
# 0      RATIONALE: Drugs used in chemotherapy use diff...        1997
# 6      RATIONALE: Drugs used in chemotherapy use diff...        2000
# 7      RATIONALE: Drugs used in chemotherapy use diff...        2000
# 8      Primary objective: - Compare disease-free surv...        2001
# 9      Pompe disease is caused by a deficiency of a c...        2001
# 10     A study to determine the effect on prevention ...        2001
# 11     To assess the effect on weight loss and weight...        2001
# 12     To assess the effect on weight loss and weight...        2001
# 13     To assess the effects of weight loss and weigh...        2001
# 14     The study is designed to assess the efficacy o...        2001
# 15     This is a randomized, double-blind, placebo-co...        2001
# 16     Approximately 300 patients will be entered int...        2002
# 17     The purpose of this study is to assess the eff...        2002
# 18     Clofarabine (injection) is approved by the Foo...        2002
# 19     Clofarabine (injection) is approved by the Foo...        2002
# 20     Patients experiencing a mild heart attack will...        2001
# 21     The purpose of this study is to assess the eff...        2001
# 22     The purpose of this study is to investigate th...        2002
# 23     The purpose of this study is to investigate th...        2002
# 24     Clofarabine (injection) is approved by the Foo...        2002
# 25     The purpose of this study is to assess the lon...        2002
# 26     The purpose of this study is to compare the sa...        2002
# 27     The purposes of the study is to determine whet...        2001
# 28     The purpose of the study is to compare the eff...        2002
# 29     This is a Phase III, open-label, multicenter, ...        2001
# 30     The primary objective is to assess the efficac...        2002
# 31     The purpose of this study is to assess the eff...        2002
# 32     The primary purpose of this study is to determ...        2002
# 33     This was a Phase II, randomized, open-label, r...        2002
# 34     RATIONALE: - Atherothrombosis is a progressive...        2002
# ...                                                  ...         ...
# 13585  This study will evaluate the safety, tolerabil...        2005
# 13587  This single-center, randomized, open-label, pi...        2004
# 13588  This study evaluated the efficacy and safety o...        2005
# 13589  This is an open-label, randomized and multi-ce...        2004
# 13590  This study will evaluate the efficacy, safety ...        2003
# 13591  This study involves a two-part design. Part 1 ...        2016
# 13594  This study will assess the efficacy and safety...        2002
# 13595  This randomized, multi-center, Phase IV, compa...        2005
# 13599  This study will assess potentially predictive ...        2005
# 13600  This study will assess the prophylactic effect...        2006
# 13603  This is an expanded access, multicenter, natio...        2006
# 13604  This is a longitudinal, follow-up study in par...        2016
# 13607  This study evaluated the safety and efficacy o...        2004
# 13611  This is a multicenter, randomized, double-blin...        2016
# 13612  This open label extension study will give an o...        2004
# 13614  This study will evaluate the efficacy and safe...        2004
# 13617  This study will evaluate the pharmacokinetics ...        2004
# 13624  This is a Phase I, open-label, multicenter stu...        2016
# 13632  This prospective pilot study will assess the f...        2016
# 13636  This is a multi-center, non-randomized, open-l...        2016
# 13637  This multicenter, non-randomized, Phase II stu...        2016
# 13638  This is a Phase IIa/b double-blind, placebo-co...        2016
# 13645  This is a Phase II, multicenter, randomized, a...        2017
# 13659  This is an open-label Phase I study of single-...        2017
# 13663  This is a non-randomized, open-label, one-trea...        2017
# 13666  The purpose of this study is to characterize t...        2017
# 13676  This proof-of-mechanism study is being perform...        2017
# 13686  This is a Phase I, multi-center, randomized, a...        2017
# 13696  This single-center, open-label study will eval...        2018
# 13714  This is a single dose (SD), non-randomized, op...        2018
#
#        Start_Month            Phase  Enrollment     Status  \
# 0                7          Phase 2          75  Completed
# 6               12          Phase 3           0  Completed
# 7                7          Phase 3           0  Completed
# 8                4          Phase 3        3222  Completed
# 9                5          Phase 2           8  Completed
# 10               5          Phase 3        1522  Completed
# 11               9          Phase 3        1033  Completed
# 12              10          Phase 3        1045  Completed
# 13               8          Phase 3        3045  Completed
# 14               6          Phase 2          35  Completed
# 15               8          Phase 2         338  Completed
# 16               2          Phase 2         300  Completed
# 17               5          Phase 2          44  Completed
# 18               5          Phase 2          60  Completed
# 19               5          Phase 2          40  Completed
# 20               8          Phase 3        8000  Completed
# 21               5          Phase 3         170  Completed
# 22               3          Phase 3        1000  Completed
# 23               2          Phase 3        1000  Completed
# 24               5          Phase 2          40  Completed
# 25               2          Phase 3        1200  Completed
# 26               5          Phase 3          59  Completed
# 27              11          Phase 3         240  Completed
# 28              11          Phase 3         250  Completed
# 29               7          Phase 3         284  Completed
# 30              10          Phase 2          30  Completed
# 31              10          Phase 2         129  Completed
# 32              11  Phase 1/Phase 2          30  Completed
# 33              12          Phase 2         334  Completed
# 34              10          Phase 3       15603  Completed
# ...            ...              ...         ...        ...
# 13585            5  Phase 1/Phase 2          48  Completed
# 13587            9          Phase 2          12  Completed
# 13588           10          Phase 3          31  Completed
# 13589           12          Phase 3          84  Completed
# 13590            9          Phase 3          41  Completed
# 13591            6          Phase 1          88  Completed
# 13594            2          Phase 2         225  Completed
# 13595            4          Phase 4         180  Completed
# 13599            7          Phase 2         264  Completed
# 13600            6          Phase 4          53  Completed
# 13603            1          Phase 4          24  Completed
# 13604            7          Phase 1           4  Completed
# 13607            6          Phase 3          81  Completed
# 13611            6          Phase 1          33  Completed
# 13612            1  Phase 2/Phase 3           9  Completed
# 13614            3          Phase 2         182  Completed
# 13617            2          Phase 4          63  Completed
# 13624           12          Phase 1          18  Completed
# 13632           11          UNKNOWN         100  Completed
# 13636           12          Phase 1          29  Completed
# 13637           12          Phase 2          20  Completed
# 13638           12          Phase 2         119  Completed
# 13645            1          Phase 2          76  Completed
# 13659            6          Phase 1          11  Completed
# 13663            7          Phase 1          20  Completed
# 13666            6          Phase 1          21  Completed
# 13676           10          Phase 2          12  Completed
# 13686           10          Phase 1          27  Completed
# 13696            3          Phase 1          16  Completed
# 13714            4          Phase 1          15  Completed
#
#                                      Condition  month_year  \
# 0                                     Leukemia  1997-07-01
# 6                         Colorectal Neoplasms  2000-12-01
# 7               Carcinoma, Non-Small-Cell Lung  2000-07-01
# 8                             Breast Neoplasms  2001-04-01
# 9             Glycogen Storage Disease Type II  2001-05-01
# 10                           Urinary Retention  2001-05-01
# 11                               Dyslipidemias  2001-09-01
# 12                                     Obesity  2001-10-01
# 13                                 Weight Loss  2001-08-01
# 14                                Hyponatremia  2001-06-01
# 15                               Heart Failure  2001-08-01
# 16                                    Diarrhea  2002-02-01
# 17                            Breast Neoplasms  2002-05-01
# 18                                    Leukemia  2002-05-01
# 19                                    Leukemia  2002-05-01
# 20                       Myocardial Infarction  2001-08-01
# 21                           Diabetes Mellitus  2001-05-01
# 22                                      Asthma  2002-03-01
# 23                                      Asthma  2002-02-01
# 24                                    Leukemia  2002-05-01
# 25                                      Asthma  2002-02-01
# 26                   Diabetes Mellitus, Type 1  2002-05-01
# 27                           Diabetes Mellitus  2001-11-01
# 28                           Diabetes Mellitus  2002-11-01
# 29      Leukemia, Lymphocytic, Chronic, B-Cell  2001-07-01
# 30                            Multiple Myeloma  2002-10-01
# 31              Carcinoma, Non-Small-Cell Lung  2002-10-01
# 32                       Carcinoma, Renal Cell  2002-11-01
# 33     Multiple Sclerosis, Relapsing-Remitting  2002-12-01
# 34                            Arteriosclerosis  2002-10-01
# ...                                        ...         ...
# 13585                    Lymphoma, Non-Hodgkin  2005-05-01
# 13587                     Hepatitis D, Chronic  2004-09-01
# 13588                       Hepatitis, Chronic  2005-10-01
# 13589                           HIV Infections  2004-12-01
# 13590                                 Leukemia  2003-09-01
# 13591                         Breast Neoplasms  2016-06-01
# 13594                         Breast Neoplasms  2002-02-01
# 13595                                Hepatitis  2005-04-01
# 13599                           Lung Neoplasms  2005-07-01
# 13600                    Lymphoma, Non-Hodgkin  2006-06-01
# 13603                       Hepatitis, Chronic  2006-01-01
# 13604                        Alzheimer Disease  2016-07-01
# 13607                                Hepatitis  2004-06-01
# 13611                            Schizophrenia  2016-06-01
# 13612                                 Leukemia  2004-01-01
# 13614                         Breast Neoplasms  2004-03-01
# 13617                     Hepatitis C, Chronic  2004-02-01
# 13624                           Lung Neoplasms  2016-12-01
# 13632                       Multiple Sclerosis  2016-11-01
# 13636                      Renal Insufficiency  2016-12-01
# 13637                Urinary Bladder Neoplasms  2016-12-01
# 13638                    Arthritis, Rheumatoid  2016-12-01
# 13645                     Macular Degeneration  2017-01-01
# 13659                         Breast Neoplasms  2017-06-01
# 13663                 Urinary Tract Infections  2017-07-01
# 13666       Gram-Negative Bacterial Infections  2017-06-01
# 13676                         beta-Thalassemia  2017-10-01
# 13686                     Glaucoma, Open-Angle  2017-10-01
# 13696                             Hemophilia A  2018-03-01
# 13714                 Autism Spectrum Disorder  2018-04-01
#
#                     phase_status
# 0              Phase 2_Completed
# 6              Phase 3_Completed
# 7              Phase 3_Completed
# 8              Phase 3_Completed
# 9              Phase 2_Completed
# 10             Phase 3_Completed
# 11             Phase 3_Completed
# 12             Phase 3_Completed
# 13             Phase 3_Completed
# 14             Phase 2_Completed
# 15             Phase 2_Completed
# 16             Phase 2_Completed
# 17             Phase 2_Completed
# 18             Phase 2_Completed
# 19             Phase 2_Completed
# 20             Phase 3_Completed
# 21             Phase 3_Completed
# 22             Phase 3_Completed
# 23             Phase 3_Completed
# 24             Phase 2_Completed
# 25             Phase 3_Completed
# 26             Phase 3_Completed
# 27             Phase 3_Completed
# 28             Phase 3_Completed
# 29             Phase 3_Completed
# 30             Phase 2_Completed
# 31             Phase 2_Completed
# 32     Phase 1/Phase 2_Completed
# 33             Phase 2_Completed
# 34             Phase 3_Completed
# ...                          ...
# 13585  Phase 1/Phase 2_Completed
# 13587          Phase 2_Completed
# 13588          Phase 3_Completed
# 13589          Phase 3_Completed
# 13590          Phase 3_Completed
# 13591          Phase 1_Completed
# 13594          Phase 2_Completed
# 13595          Phase 4_Completed
# 13599          Phase 2_Completed
# 13600          Phase 4_Completed
# 13603          Phase 4_Completed
# 13604          Phase 1_Completed
# 13607          Phase 3_Completed
# 13611          Phase 1_Completed
# 13612  Phase 2/Phase 3_Completed
# 13614          Phase 2_Completed
# 13617          Phase 4_Completed
# 13624          Phase 1_Completed
# 13632          UNKNOWN_Completed
# 13636          Phase 1_Completed
# 13637          Phase 2_Completed
# 13638          Phase 2_Completed
# 13645          Phase 2_Completed
# 13659          Phase 1_Completed
# 13663          Phase 1_Completed
# 13666          Phase 1_Completed
# 13676          Phase 2_Completed
# 13686          Phase 1_Completed
# 13696          Phase 1_Completed
# 13714          Phase 1_Completed
#
# [10568 rows x 12 columns]
